# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Year Order Item Data.csv", parse_dates=['date'])

df.to_dict(orient="records")
# Out:
# [{'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 1,
#   'date': Timestamp('2024-04-01 11:32:59'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8390406775.0,
#   'customer_name': 'slma saphir',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 344.23,
#   'total_tax': 30.78,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 375,
#   'item_name': 'Strawberry Shake (Milkshake)',
#   'category_name': 'Classic Shakes',
#   'sap_code': nan,
#   'item_price': 160.64,
#   'item_quantity': 1,
#   'item_total': 160.64},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 1,
#   'date': Timestamp('2024-04-01 11:32:59'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8390406775.0,
#   'customer_name': 'slma saphir',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 344.23,
#   'total_tax': 30.78,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 375,
#   'item_name': 'Chocolate Shake (Milkshake)',
#   'category_name': 'Instashakes',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 2,
#   'date': Timestamp('2024-04-01 12:05:34'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9373994697.0,
#   'customer_name': 'rahat khan',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 137.69,
#   'total_tax': 12.3,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.01,
#   'total': 150,
#   'item_name': 'Classic Lemonade',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 137.69,
#   'item_quantity': 1,
#   'item_total': 137.69},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 3,
#   'date': Timestamp('2024-04-01 12:12:00'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8149380773.0,
#   'customer_name': 'sania khan',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 367.18,
#   'total_tax': 32.82,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 400,
#   'item_name': 'Waffles',
#   'category_name': 'Waffles',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 2,
#   'item_total': 367.18},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 4,
#   'date': Timestamp('2024-04-01 12:13:51'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9156525137.0,
#   'customer_name': 'pawna mothkuwan',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 367.18,
#   'total_tax': 32.82,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 400,
#   'item_name': 'Banana Shake (Milkshake)',
#   'category_name': 'Fruit Walker',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 4,
#   'date': Timestamp('2024-04-01 12:13:51'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9156525137.0,
#   'customer_name': 'pawna mothkuwan',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 367.18,
#   'total_tax': 32.82,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 400,
#   'item_name': 'Chocolate Shake (Milkshake)',
#   'category_name': 'Instashakes',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 5,
#   'date': Timestamp('2024-04-01 14:32:03'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9405066992.0,
#   'customer_name': 'ghule patil',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 504.87,
#   'total_tax': 45.14,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 550,
#   'item_name': 'Wonder Vanilla Shake (Milkshake)',
#   'category_name': 'Classic Shakes',
#   'sap_code': nan,
#   'item_price': 160.64,
#   'item_quantity': 2,
#   'item_total': 321.28},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 5,
#   'date': Timestamp('2024-04-01 14:32:03'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9405066992.0,
#   'customer_name': 'ghule patil',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 504.87,
#   'total_tax': 45.14,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 550,
#   'item_name': 'Chocolate Shake (Milkshake)',
#   'category_name': 'Instashakes',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 6,
#   'date': Timestamp('2024-04-01 14:34:38'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9182683151.0,
#   'customer_name': 'ishrath',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 367.18,
#   'total_tax': 32.82,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 400,
#   'item_name': 'Chocolate Shake (Milkshake)',
#   'category_name': 'Instashakes',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 6,
#   'date': Timestamp('2024-04-01 14:34:38'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9182683151.0,
#   'customer_name': 'ishrath',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 367.18,
#   'total_tax': 32.82,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 400,
#   'item_name': 'Caramel Shake (Milkshake)',
#   'category_name': 'Instashakes',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 7,
#   'date': Timestamp('2024-04-01 15:10:59'),
#   'payment_type': 'CARD',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9595959573.0,
#   'customer_name': 'naresh gadhekar',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 160.64,
#   'total_tax': 14.36,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 175,
#   'item_name': 'Blackcurrant Shake (Milkshake)',
#   'category_name': 'Classic Shakes',
#   'sap_code': nan,
#   'item_price': 160.64,
#   'item_quantity': 1,
#   'item_total': 160.64},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 8,
#   'date': Timestamp('2024-04-01 15:17:01'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 7709197868.0,
#   'customer_name': nan,
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 367.18,
#   'total_tax': 32.82,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 400,
#   'item_name': 'Chocolate Shake (Milkshake)',
#   'category_name': 'Instashakes',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 2,
#   'item_total': 367.18},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 9,
#   'date': Timestamp('2024-04-01 16:05:23'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9403955555.0,
#   'customer_name': 'manoj varma',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 403.89,
#   'total_tax': 36.1,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.01,
#   'total': 440,
#   'item_name': 'Dry Fruit Shake (Milkshake)',
#   'category_name': 'Mom Special Shakes',
#   'sap_code': nan,
#   'item_price': 220.3,
#   'item_quantity': 1,
#   'item_total': 220.3},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 9,
#   'date': Timestamp('2024-04-01 16:05:23'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9403955555.0,
#   'customer_name': 'manoj varma',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 403.89,
#   'total_tax': 36.1,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.01,
#   'total': 440,
#   'item_name': 'Coffee Shake (Milkshake)',
#   'category_name': 'Instashakes',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 10,
#   'date': Timestamp('2024-04-01 16:14:16'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 7219777853.0,
#   'customer_name': 'aditi kulkarni',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 275.38,
#   'total_tax': 24.62,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 300,
#   'item_name': 'Cold Coffee',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 137.69,
#   'item_quantity': 2,
#   'item_total': 275.38},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 11,
#   'date': Timestamp('2024-04-01 16:42:41'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8767952689.0,
#   'customer_name': 'vidhi',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 220.3,
#   'total_tax': 19.7,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 240,
#   'item_name': 'Nutella Brownie Shake (Milkshake)',
#   'category_name': 'Mom Special Shakes',
#   'sap_code': nan,
#   'item_price': 220.3,
#   'item_quantity': 1,
#   'item_total': 220.3},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 12,
#   'date': Timestamp('2024-04-01 16:57:42'),
#   'payment_type': 'CARD',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9422928165.0,
#   'customer_name': 'shirish',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 376.36,
#   'total_tax': 33.64,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 410,
#   'item_name': 'Waffles',
#   'category_name': 'Waffles',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 12,
#   'date': Timestamp('2024-04-01 16:57:42'),
#   'payment_type': 'CARD',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9422928165.0,
#   'customer_name': 'shirish',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 376.36,
#   'total_tax': 33.64,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 410,
#   'item_name': 'Strawberry Shake (Thickshake)',
#   'category_name': 'Classic Shakes',
#   'sap_code': nan,
#   'item_price': 192.77,
#   'item_quantity': 1,
#   'item_total': 192.77},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 13,
#   'date': Timestamp('2024-04-01 17:00:06'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8788213089.0,
#   'customer_name': nan,
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 229.48,
#   'total_tax': 20.52,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 250,
#   'item_name': 'Oreo Brownie Shake (Thickshake)',
#   'category_name': 'Coco Bros',
#   'sap_code': nan,
#   'item_price': 229.48,
#   'item_quantity': 1,
#   'item_total': 229.48},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 14,
#   'date': Timestamp('2024-04-01 17:41:57'),
#   'payment_type': 'CARD',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8275050786.0,
#   'customer_name': 'JAVED SIDHIQU',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 183.59,
#   'total_tax': 16.42,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 200,
#   'item_name': 'Chocolate Shake (Milkshake)',
#   'category_name': 'Instashakes',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 15,
#   'date': Timestamp('2024-04-01 18:03:57'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': nan,
#   'customer_name': nan,
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 183.59,
#   'total_tax': 16.42,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 200,
#   'item_name': 'Waffles',
#   'category_name': 'Waffles',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 16,
#   'date': Timestamp('2024-04-01 18:15:50'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8626070439.0,
#   'customer_name': 'abhishek',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 229.48,
#   'total_tax': 20.52,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 250,
#   'item_name': 'Chocolate Brownie Shake (Thickshake)',
#   'category_name': 'Coco Bros',
#   'sap_code': nan,
#   'item_price': 229.48,
#   'item_quantity': 1,
#   'item_total': 229.48},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 17,
#   'date': Timestamp('2024-04-01 18:21:20'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9421683538.0,
#   'customer_name': 'dm muglikar',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 321.28,
#   'total_tax': 28.72,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 350,
#   'item_name': 'Strawberry Shake (Milkshake)',
#   'category_name': 'Classic Shakes',
#   'sap_code': nan,
#   'item_price': 160.64,
#   'item_quantity': 2,
#   'item_total': 321.28},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 18,
#   'date': Timestamp('2024-04-01 19:10:28'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9623654888.0,
#   'customer_name': 'fatim khan',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 160.64,
#   'total_tax': 14.36,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 175,
#   'item_name': 'Blackcurrant Shake (Milkshake)',
#   'category_name': 'Classic Shakes',
#   'sap_code': nan,
#   'item_price': 160.64,
#   'item_quantity': 1,
#   'item_total': 160.64},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 19,
#   'date': Timestamp('2024-04-01 19:22:56'),
#   'payment_type': 'CARD',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9860798115.0,
#   'customer_name': 'yashabh agrawal',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 137.69,
#   'total_tax': 12.3,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.01,
#   'total': 150,
#   'item_name': 'Chilli Guava',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 137.69,
#   'item_quantity': 1,
#   'item_total': 137.69},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 20,
#   'date': Timestamp('2024-04-01 19:51:19'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9689918305.0,
#   'customer_name': 'MAHINDRA',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 220.3,
#   'total_tax': 19.7,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 240,
#   'item_name': 'Kulfi Nuts Shake (Milkshake)',
#   'category_name': 'Mom Special Shakes',
#   'sap_code': nan,
#   'item_price': 220.3,
#   'item_quantity': 1,
#   'item_total': 220.3},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 21,
#   'date': Timestamp('2024-04-01 20:09:15'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8767249912.0,
#   'customer_name': 'MANINDAR KAUR',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 183.59,
#   'total_tax': 16.42,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 200,
#   'item_name': 'Coffee Shake (Milkshake)',
#   'category_name': 'Instashakes',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 22,
#   'date': Timestamp('2024-04-01 20:20:54'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': nan,
#   'customer_name': nan,
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 477.33,
#   'total_tax': 42.68,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 520,
#   'item_name': 'Cold Coffee',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 137.69,
#   'item_quantity': 2,
#   'item_total': 275.38},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 22,
#   'date': Timestamp('2024-04-01 20:20:54'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': nan,
#   'customer_name': nan,
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 477.33,
#   'total_tax': 42.68,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 520,
#   'item_name': 'Coffee Brownie Shake (Milkshake)',
#   'category_name': 'Coco Bros',
#   'sap_code': nan,
#   'item_price': 201.95,
#   'item_quantity': 1,
#   'item_total': 201.95},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 23,
#   'date': Timestamp('2024-04-01 20:42:37'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8551022205.0,
#   'customer_name': 'vaishali rathod',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 183.59,
#   'total_tax': 16.42,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 200,
#   'item_name': 'Waffles',
#   'category_name': 'Waffles',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 24,
#   'date': Timestamp('2024-04-01 21:12:17'),
#   'payment_type': 'CARD',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9682312239.0,
#   'customer_name': 'AJAY SONAWNE',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 550.76,
#   'total_tax': 49.24,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 600,
#   'item_name': 'Cold Coffee',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 137.69,
#   'item_quantity': 4,
#   'item_total': 550.76},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 25,
#   'date': Timestamp('2024-04-01 21:38:29'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': nan,
#   'customer_name': nan,
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 156.05,
#   'total_tax': 13.96,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 170,
#   'item_name': 'Waffles',
#   'category_name': 'Waffles',
#   'sap_code': nan,
#   'item_price': 156.05,
#   'item_quantity': 1,
#   'item_total': 156.05},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 26,
#   'date': Timestamp('2024-04-01 21:39:45'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 7276114686.0,
#   'customer_name': 'kapil',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 220.3,
#   'total_tax': 19.7,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 240,
#   'item_name': 'Dry Fruit Shake (Milkshake)',
#   'category_name': 'Mom Special Shakes',
#   'sap_code': nan,
#   'item_price': 220.3,
#   'item_quantity': 1,
#   'item_total': 220.3},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 27,
#   'date': Timestamp('2024-04-01 21:43:47'),
#   'payment_type': 'CARD',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9223581889.0,
#   'customer_name': 'kamesh',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 211.13,
#   'total_tax': 18.88,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 230,
#   'item_name': 'Mango Shake (Thickshake)',
#   'category_name': 'Fruit Walker',
#   'sap_code': nan,
#   'item_price': 211.13,
#   'item_quantity': 1,
#   'item_total': 211.13},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 28,
#   'date': Timestamp('2024-04-02 11:31:14'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 7499171874.0,
#   'customer_name': 'rahul darwande',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 348.82,
#   'total_tax': 31.18,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 380,
#   'item_name': 'Mango Shake (Thickshake)',
#   'category_name': 'Fruit Walker',
#   'sap_code': nan,
#   'item_price': 211.13,
#   'item_quantity': 1,
#   'item_total': 211.13},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 28,
#   'date': Timestamp('2024-04-02 11:31:14'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 7499171874.0,
#   'customer_name': 'rahul darwande',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 348.82,
#   'total_tax': 31.18,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 380,
#   'item_name': 'Classic Lemonade',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 137.69,
#   'item_quantity': 1,
#   'item_total': 137.69},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 29,
#   'date': Timestamp('2024-04-02 12:23:34'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8888253200.0,
#   'customer_name': 'tanish pawar',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 275.38,
#   'total_tax': 24.62,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 300,
#   'item_name': 'Classic Lemonade',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 137.69,
#   'item_quantity': 1,
#   'item_total': 137.69},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 29,
#   'date': Timestamp('2024-04-02 12:23:34'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8888253200.0,
#   'customer_name': 'tanish pawar',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 275.38,
#   'total_tax': 24.62,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 300,
#   'item_name': 'Blue Curacao',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 137.69,
#   'item_quantity': 1,
#   'item_total': 137.69},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 30,
#   'date': Timestamp('2024-04-02 12:37:13'),
#   'payment_type': 'CARD',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8180874884.0,
#   'customer_name': 'harshala sonone',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 481.92,
#   'total_tax': 43.08,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 525,
#   'item_name': 'Strawberry Shake (Milkshake)',
#   'category_name': 'Classic Shakes',
#   'sap_code': nan,
#   'item_price': 160.64,
#   'item_quantity': 3,
#   'item_total': 481.919999999999},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 31,
#   'date': Timestamp('2024-04-02 14:30:54'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9422217263.0,
#   'customer_name': 'SACHIN MANTRI',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 183.59,
#   'total_tax': 16.42,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 200,
#   'item_name': 'Oreo Shake (Milkshake)',
#   'category_name': 'Instashakes',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 32,
#   'date': Timestamp('2024-04-02 15:51:01'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9403410977.0,
#   'customer_name': 'anjali patil',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 137.69,
#   'total_tax': 12.3,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.01,
#   'total': 150,
#   'item_name': 'Cold Coffee',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 137.69,
#   'item_quantity': 1,
#   'item_total': 137.69},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 33,
#   'date': Timestamp('2024-04-02 15:58:36'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8275806406.0,
#   'customer_name': 'sachin jaiswal',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 137.69,
#   'total_tax': 12.3,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.01,
#   'total': 150,
#   'item_name': 'Cold Coffee',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 137.69,
#   'item_quantity': 1,
#   'item_total': 137.69},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 34,
#   'date': Timestamp('2024-04-02 16:07:53'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8767140902.0,
#   'customer_name': 'rutvik wankhede',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 550.76,
#   'total_tax': 49.24,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 600,
#   'item_name': 'Cold Coffee',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 137.69,
#   'item_quantity': 4,
#   'item_total': 550.76},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 35,
#   'date': Timestamp('2024-04-02 16:12:14'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 7058731612.0,
#   'customer_name': 'shrawani kale',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 183.59,
#   'total_tax': 16.42,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 200,
#   'item_name': 'Waffles',
#   'category_name': 'Waffles',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 36,
#   'date': Timestamp('2024-04-02 16:15:25'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 7499171874.0,
#   'customer_name': 'rahul darwande',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 211.13,
#   'total_tax': 18.88,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 230,
#   'item_name': 'Mango Shake (Thickshake)',
#   'category_name': 'Fruit Walker',
#   'sap_code': nan,
#   'item_price': 211.13,
#   'item_quantity': 1,
#   'item_total': 211.13},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 37,
#   'date': Timestamp('2024-04-02 16:31:05'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8554982515.0,
#   'customer_name': 'mahesh bavge',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 403.89,
#   'total_tax': 36.1,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.01,
#   'total': 440,
#   'item_name': 'Waffles',
#   'category_name': 'Waffles',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 37,
#   'date': Timestamp('2024-04-02 16:31:05'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8554982515.0,
#   'customer_name': 'mahesh bavge',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 403.89,
#   'total_tax': 36.1,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.01,
#   'total': 440,
#   'item_name': 'Kulfi Nuts Shake (Milkshake)',
#   'category_name': 'Mom Special Shakes',
#   'sap_code': nan,
#   'item_price': 220.3,
#   'item_quantity': 1,
#   'item_total': 220.3},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 38,
#   'date': Timestamp('2024-04-02 16:43:19'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9595995995.0,
#   'customer_name': 'ovee patil',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 229.48,
#   'total_tax': 20.52,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 250,
#   'item_name': 'Oreo Brownie Shake (Thickshake)',
#   'category_name': 'Coco Bros',
#   'sap_code': nan,
#   'item_price': 229.48,
#   'item_quantity': 1,
#   'item_total': 229.48},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 39,
#   'date': Timestamp('2024-04-02 16:45:05'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9595995995.0,
#   'customer_name': 'ovee patil',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 137.69,
#   'total_tax': 12.3,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.01,
#   'total': 150,
#   'item_name': 'Strawberry Cooler',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 137.69,
#   'item_quantity': 1,
#   'item_total': 137.69},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 40,
#   'date': Timestamp('2024-04-02 16:55:13'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8309593003.0,
#   'customer_name': 'deepika',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 229.48,
#   'total_tax': 20.52,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 250,
#   'item_name': 'Coffee Brownie Shake (Thickshake)',
#   'category_name': 'Coco Bros',
#   'sap_code': nan,
#   'item_price': 229.48,
#   'item_quantity': 1,
#   'item_total': 229.48},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 41,
#   'date': Timestamp('2024-04-02 16:57:10'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8309593003.0,
#   'customer_name': 'deepika',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 156.05,
#   'total_tax': 13.96,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 170,
#   'item_name': 'Waffles',
#   'category_name': 'Waffles',
#   'sap_code': nan,
#   'item_price': 156.05,
#   'item_quantity': 1,
#   'item_total': 156.05},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 42,
#   'date': Timestamp('2024-04-02 17:02:50'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9527976738.0,
#   'customer_name': 'jagdish nandapurkar',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 183.59,
#   'total_tax': 16.42,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 200,
#   'item_name': 'Chocolate Shake (Milkshake)',
#   'category_name': 'Instashakes',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 43,
#   'date': Timestamp('2024-04-02 17:06:21'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 7028707485.0,
#   'customer_name': 'akshay misal',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 431.43,
#   'total_tax': 38.56,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.01,
#   'total': 470,
#   'item_name': 'Oreo Shake (Milkshake)',
#   'category_name': 'Instashakes',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 43,
#   'date': Timestamp('2024-04-02 17:06:21'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 7028707485.0,
#   'customer_name': 'akshay misal',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 431.43,
#   'total_tax': 38.56,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.01,
#   'total': 470,
#   'item_name': 'Dry Fruit Shake (Milkshake)',
#   'category_name': 'Mom Special Shakes',
#   'sap_code': nan,
#   'item_price': 247.84,
#   'item_quantity': 1,
#   'item_total': 247.84},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 44,
#   'date': Timestamp('2024-04-02 17:24:05'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': nan,
#   'customer_name': nan,
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 481.92,
#   'total_tax': 43.08,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 525,
#   'item_name': 'Choco-Chip Banana Shake (Milkshake)',
#   'category_name': 'Fruit Walker',
#   'sap_code': nan,
#   'item_price': 183.59,
#   'item_quantity': 1,
#   'item_total': 183.59},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 44,
#   'date': Timestamp('2024-04-02 17:24:05'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': nan,
#   'customer_name': nan,
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 481.92,
#   'total_tax': 43.08,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 525,
#   'item_name': 'Cold Coffee',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 137.69,
#   'item_quantity': 1,
#   'item_total': 137.69},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 44,
#   'date': Timestamp('2024-04-02 17:24:05'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': nan,
#   'customer_name': nan,
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 481.92,
#   'total_tax': 43.08,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 525,
#   'item_name': 'Wonder Vanilla Shake (Milkshake)',
#   'category_name': 'Classic Shakes',
#   'sap_code': nan,
#   'item_price': 160.64,
#   'item_quantity': 1,
#   'item_total': 160.64},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 45,
#   'date': Timestamp('2024-04-02 17:26:27'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': nan,
#   'customer_name': nan,
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 183.59,
#   'total_tax': 16.42,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 200,
#   'item_name': 'Strawberry Banana Shake (Milkshake)',
# ...
#   'item_total': 228.57},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 746,
#   'date': Timestamp('2024-04-21 22:36:48'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9422532636.0,
#   'customer_name': 'SARDUL JADHAV',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 142.86,
#   'total_tax': 7.14,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 150,
#   'item_name': 'Cold Coffee',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 142.86,
#   'item_quantity': 1,
#   'item_total': 142.86},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 747,
#   'date': Timestamp('2024-04-22 11:51:41'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9049394700.0,
#   'customer_name': 'nagre',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 380.96,
#   'total_tax': 19.04,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 400,
#   'item_name': 'Munch Shake (Milkshake)',
#   'category_name': 'Instashakes',
#   'sap_code': nan,
#   'item_price': 190.48,
#   'item_quantity': 1,
#   'item_total': 190.48},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 747,
#   'date': Timestamp('2024-04-22 11:51:41'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9049394700.0,
#   'customer_name': 'nagre',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 380.96,
#   'total_tax': 19.04,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 400,
#   'item_name': 'Oreo Shake (Milkshake)',
#   'category_name': 'Instashakes',
#   'sap_code': nan,
#   'item_price': 190.48,
#   'item_quantity': 1,
#   'item_total': 190.48},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 748,
#   'date': Timestamp('2024-04-22 12:22:31'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9158495487.0,
#   'customer_name': 'jaydipa',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 142.86,
#   'total_tax': 7.14,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 150,
#   'item_name': 'Cold Coffee',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 142.86,
#   'item_quantity': 1,
#   'item_total': 142.86},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 749,
#   'date': Timestamp('2024-04-22 12:51:37'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': nan,
#   'customer_name': nan,
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 190.48,
#   'total_tax': 9.52,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 200,
#   'item_name': 'Chocolate Shake (Milkshake)',
#   'category_name': 'Instashakes',
#   'sap_code': nan,
#   'item_price': 190.48,
#   'item_quantity': 1,
#   'item_total': 190.48},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 750,
#   'date': Timestamp('2024-04-22 14:22:31'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9373907733.0,
#   'customer_name': 'Sadik khan',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 219.05,
#   'total_tax': 10.96,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 230,
#   'item_name': 'Mango Shake (Thickshake)',
#   'category_name': 'Fruit Walker',
#   'sap_code': nan,
#   'item_price': 219.05,
#   'item_quantity': 1,
#   'item_total': 219.05},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 751,
#   'date': Timestamp('2024-04-22 16:36:57'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 8830488280.0,
#   'customer_name': 'SACHIN SHINDE',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 438.1,
#   'total_tax': 21.9,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 460,
#   'item_name': 'Strawberry Banana Shake (Thickshake)',
#   'category_name': 'Fruit Walker',
#   'sap_code': nan,
#   'item_price': 219.05,
#   'item_quantity': 2,
#   'item_total': 438.1},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 752,
#   'date': Timestamp('2024-04-22 16:41:19'),
#   'payment_type': 'Online',
#   'order_type': 'Delivery(Parcel)',
#   'status': 'Success',
#   'area': 'Zomato',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Online Menu',
#   'assign_to': nan,
#   'customer_phone': nan,
#   'customer_name': 'Nazimafaisal2',
#   'customer_address': ' Rashidpura, N 10, Cidco, Aurangabad Aurangabad India',
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 725.0,
#   'total_tax': 27.26,
#   'discount': 180.0,
#   'delivery_charge': 0,
#   'container_charge': 15,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.26,
#   'total': 587,
#   'item_name': 'Chilli Guava Cooler',
#   'category_name': 'Cooler [O]',
#   'sap_code': nan,
#   'item_price': 180.0,
#   'item_quantity': 1,
#   'item_total': 180.0},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 752,
#   'date': Timestamp('2024-04-22 16:41:19'),
#   'payment_type': 'Online',
#   'order_type': 'Delivery(Parcel)',
#   'status': 'Success',
#   'area': 'Zomato',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Online Menu',
#   'assign_to': nan,
#   'customer_phone': nan,
#   'customer_name': 'Nazimafaisal2',
#   'customer_address': ' Rashidpura, N 10, Cidco, Aurangabad Aurangabad India',
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 725.0,
#   'total_tax': 27.26,
#   'discount': 180.0,
#   'delivery_charge': 0,
#   'container_charge': 15,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.26,
#   'total': 587,
#   'item_name': 'Cookie N Cream Shake (Milkshake)',
#   'category_name': 'Mom Special Shakes [O]',
#   'sap_code': nan,
#   'item_price': 285.0,
#   'item_quantity': 1,
#   'item_total': 285.0},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 752,
#   'date': Timestamp('2024-04-22 16:41:19'),
#   'payment_type': 'Online',
#   'order_type': 'Delivery(Parcel)',
#   'status': 'Success',
#   'area': 'Zomato',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Online Menu',
#   'assign_to': nan,
#   'customer_phone': nan,
#   'customer_name': 'Nazimafaisal2',
#   'customer_address': ' Rashidpura, N 10, Cidco, Aurangabad Aurangabad India',
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 725.0,
#   'total_tax': 27.26,
#   'discount': 180.0,
#   'delivery_charge': 0,
#   'container_charge': 15,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.26,
#   'total': 587,
#   'item_name': 'Oreo Brownie (Milkshake)',
#   'category_name': 'Coco Bros [O]',
#   'sap_code': nan,
#   'item_price': 260.0,
#   'item_quantity': 1,
#   'item_total': 260.0},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 753,
#   'date': Timestamp('2024-04-22 16:42:13'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9763436060.0,
#   'customer_name': 'ROHINI MOTE',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 142.86,
#   'total_tax': 7.14,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 150,
#   'item_name': 'Cold Coffee',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 142.86,
#   'item_quantity': 1,
#   'item_total': 142.86},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 754,
#   'date': Timestamp('2024-04-22 16:59:43'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9284102794.0,
#   'customer_name': 'PRITI BANDE',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 228.57,
#   'total_tax': 11.42,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.01,
#   'total': 240,
#   'item_name': 'Custard Apple (sitaphal)',
#   'category_name': 'Mom Special Shakes',
#   'sap_code': nan,
#   'item_price': 228.57,
#   'item_quantity': 1,
#   'item_total': 228.57},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 755,
#   'date': Timestamp('2024-04-22 17:01:01'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 7030174040.0,
#   'customer_name': 'VRUSHALI MHASKE',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 200.0,
#   'total_tax': 10.0,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 210,
#   'item_name': 'Blackcurrant Crunch Shake (Milkshake)',
#   'category_name': 'Healthy Crunches',
#   'sap_code': nan,
#   'item_price': 200.0,
#   'item_quantity': 1,
#   'item_total': 200.0},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 756,
#   'date': Timestamp('2024-04-22 17:19:11'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9834908107.0,
#   'customer_name': 'ARBAJ',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 161.9,
#   'total_tax': 8.1,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 170,
#   'item_name': 'Waffles',
#   'category_name': 'Waffles',
#   'sap_code': nan,
#   'item_price': 161.9,
#   'item_quantity': 1,
#   'item_total': 161.9},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 757,
#   'date': Timestamp('2024-04-22 17:33:05'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9767093472.0,
#   'customer_name': 'MIRA SINGH',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 228.57,
#   'total_tax': 11.42,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.01,
#   'total': 240,
#   'item_name': 'Belgium Dark Chocolate Shake (Milkshake)',
#   'category_name': 'Mom Special Shakes',
#   'sap_code': nan,
#   'item_price': 228.57,
#   'item_quantity': 1,
#   'item_total': 228.57},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 758,
#   'date': Timestamp('2024-04-22 17:55:37'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9552108888.0,
#   'customer_name': 'RAJNANDANI',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 166.67,
#   'total_tax': 8.34,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.01,
#   'total': 175,
#   'item_name': 'Wonder Vanilla Shake (Milkshake)',
#   'category_name': 'Classic Shakes',
#   'sap_code': nan,
#   'item_price': 166.67,
#   'item_quantity': 1,
#   'item_total': 166.67},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 759,
#   'date': Timestamp('2024-04-22 18:05:47'),
#   'payment_type': 'Part Payment',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 7709010362.0,
#   'customer_name': 'BHAGESHREE',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 714.3,
#   'total_tax': 35.72,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.02,
#   'total': 750,
#   'item_name': 'Cold Coffee',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 142.86,
#   'item_quantity': 5,
#   'item_total': 714.3},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 760,
#   'date': Timestamp('2024-04-22 18:08:36'),
#   'payment_type': 'Other [UPI]',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': nan,
#   'customer_name': nan,
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 714.3,
#   'total_tax': 35.72,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': -0.02,
#   'total': 750,
#   'item_name': 'Cold Coffee',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 142.86,
#   'item_quantity': 5,
#   'item_total': 714.3},
#  {'restaurant_name': 'Makers of Milkshakes - Prozone Mall',
#   'invoice_no': 761,
#   'date': Timestamp('2024-04-22 18:13:59'),
#   'payment_type': 'Cash',
#   'order_type': 'Pick Up',
#   'status': 'Success',
#   'area': 'Parcel',
#   'virtual_brand_name': nan,
#   'brand_grouping': 'Offline Menu',
#   'assign_to': nan,
#   'customer_phone': 9657496444.0,
#   'customer_name': 'RATHI',
#   'customer_address': nan,
#   'persons': nan,
#   'order_cancel_reason': nan,
#   'my_amount': 142.86,
#   'total_tax': 7.14,
#   'discount': 0.0,
#   'delivery_charge': 0,
#   'container_charge': 0,
#   'service_charge': 0,
#   'additional_charge': 0,
#   'waived_off': 0,
#   'round_off': 0.0,
#   'total': 150,
#   'item_name': 'Cold Coffee',
#   'category_name': 'Coolers',
#   'sap_code': nan,
#   'item_price': 142.86,
#   'item_quantity': 1,
#   'item_total': 142.86},
#  ...]

# %%
df.dropna(subset=['date', 'item_name', 'item_quantity', 'item_total'], inplace=True)
df = df[df['status'].str.lower() == 'success']

numeric_cols = ['item_quantity', 'item_price', 'item_total', 'discount', 'waived_off']
for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

df['discount'].fillna(0, inplace=True)
df['waived_off'].fillna(0, inplace=True)

# Dropping rows with NaN after coercion
df.dropna(subset=['item_quantity', 'item_price', 'item_total'], inplace=True)

# Filter for invalid sales data
df = df[(df['item_quantity'] > 0) & (df['item_total'] > 0)]
# Out:
# C:\Users\Rikhil Nellimarla\AppData\Local\Temp\ipykernel_7084\271279476.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['discount'].fillna(0, inplace=True)
# C:\Users\Rikhil Nellimarla\AppData\Local\Temp\ipykernel_7084\271279476.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['waived_off'].fillna(0, inplace=True)

# %%
df['net_sales'] = df['item_total'] - df['discount'] - df['waived_off']
df['YearMonth'] = df['date'].dt.to_period('M')
df['Month'] = df['date'].dt.strftime('%b')  # Jan, Feb...

# %% [markdown]
# ## Yearly

# %% [markdown]
# ### Yearly: Top Selling

# %%
top_items_yearly = (
    df.groupby('item_name')['item_quantity']
    .sum()
    .reset_index()
    .sort_values(by='item_quantity', ascending=False)
)

# %%
top_items_yearly.to_csv("../results/product_analysis/yearly/Yearly_Top_Selling_Items.csv", index=False)

# %% [markdown]
# ### Yearly: Product Performance

# %%
yearly_kpis = (
    df.groupby('item_name').agg(
        total_units_sold=('item_quantity', 'sum'),
        total_net_sales=('net_sales', 'sum'),
        average_selling_price=('item_price', 'mean'),
        orders_count=('invoice_no', 'nunique')
    ).reset_index()
)

# %%
yearly_kpis['weighted_avg_price'] = yearly_kpis['total_net_sales'] / yearly_kpis['total_units_sold']
yearly_kpis.sort_values(by='total_units_sold', ascending=False, inplace=True)

# %%
yearly_kpis.to_csv("../results/product_analysis/yearly/Yearly_Product_Performance.csv", index=False)

# %% [markdown]
# ## Monthly

# %% [markdown]
# ### Monthly Top Selling

# %%
monthly_pivot = (
    df.groupby(['item_name', 'Month'])['item_quantity']
    .sum()
    .unstack(fill_value=0)
)

monthly_pivot['Total'] = monthly_pivot.sum(axis=1)
monthly_pivot = monthly_pivot.sort_values(by='Total', ascending=False)
monthly_pivot.reset_index(inplace=True)

# %%
monthly_pivot.to_csv("../results/product_analysis/monthly/Monthly_Top_Selling_Items.csv", index=False)

# %% [markdown]
# ### Monthly: Product Performance

# %%
monthly_kpis = (
    df.groupby(['YearMonth', 'item_name']).agg(
        total_units_sold=('item_quantity', 'sum'),
        total_net_sales=('net_sales', 'sum'),
        average_selling_price=('item_price', 'mean'),
    ).reset_index()
)

monthly_kpis['YearMonth'] = monthly_kpis['YearMonth'].astype(str)

# %%
monthly_kpis.to_csv("../results/product_analysis/monthly/Monthly_Product_Performance.csv", index=False)

# %% [markdown]
# ### Daily

# %%
df['Order_Date'] = df['date'].dt.date
df['DayOfWeek'] = df['date'].dt.day_name()

# %%
daily_kpis = (
    df.groupby(['Order_Date', 'DayOfWeek', 'item_name']).agg(
        total_units_sold=('item_quantity', 'sum'),
        total_net_sales=('net_sales', 'sum'),
        average_selling_price=('item_price', 'mean'),
        orders_count=('invoice_no', 'nunique')
    ).reset_index()
)

daily_kpis['weighted_avg_price'] = (
    daily_kpis['total_net_sales'] / daily_kpis['total_units_sold']
)

daily_kpis.to_csv("../results/product_analysis/daily/Daily_Product_Performance.csv", index=False)

# %%
daily_kpis.to_csv("../results/product_analysis/daily/Daily_Product_Performance.csv", index=False)

# %%
daily_pivot = (
    df.groupby(['DayOfWeek', 'item_name'])['item_quantity']
    .sum()
    .unstack(fill_value=0)
    .reindex([
        'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'
    ])
)

daily_pivot.to_csv("../results/product_analysis/daily/Daily_Item_Sales_Pivot.csv")

# %%
avg_day_kpi = (
    df.groupby('DayOfWeek').agg(
        avg_units_sold=('item_quantity', 'mean'),
        avg_net_sales=('net_sales', 'mean'),
        avg_orders=('invoice_no', 'nunique')
    ).reindex([
        'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'
    ]).reset_index()
)

avg_day_kpi.to_csv("../results/product_analysis/daily/Average_Performance_By_DayOfWeek.csv", index=False)

# %% [markdown]
# ### Hourly

# %%
df['Hour'] = df['date'].dt.hour

# %%
# aggregated table
hourly_kpis = (
    df.groupby([df['date'].dt.date, 'Hour', 'item_name']).agg(
        total_units_sold=('item_quantity', 'sum'),
        total_net_sales=('net_sales', 'sum'),
        average_selling_price=('item_price', 'mean'),
        orders_count=('invoice_no', 'nunique')
    ).reset_index()
)

hourly_kpis['weighted_avg_price'] = hourly_kpis['total_net_sales'] / hourly_kpis['total_units_sold']
hourly_kpis.rename(columns={'date': 'Order_Date'}, inplace=True)
hourly_kpis.to_csv("../results/product_analysis/hourly/Hourly_Product_Performance.csv", index=False)

# %%
# Pivot Table
pivot = df.groupby(['Hour', 'item_name'])['item_quantity'].sum().unstack(fill_value=0)
pivot.to_csv("../results/product_analysis/hourly/Hourly_Item_Sales_Pivot.csv")

# %%
# average hour performance
hour_avg_kpi = (
    df.groupby('Hour').agg(
        avg_units_sold=('item_quantity', 'mean'),
        avg_net_sales=('net_sales', 'mean'),
        avg_orders=('invoice_no', 'nunique')
    ).reset_index()
)

hour_avg_kpi.to_csv("../results/product_analysis/hourly/Average_Performance_By_Hour.csv", index=False)
